# %% [markdown]
# ### Simple ChatModel

# %%
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv

load_dotenv()

llm = ChatOpenAI(model="gpt-4o")

result = llm.invoke("What is Prompt Poisoning?")

print(result)
# Out:
# content="Prompt poisoning is a type of adversarial attack or manipulation where an input is crafted in such a way that it manipulates the output of an AI model, particularly in the context of language models or chatbots. This can involve embedding misleading, harmful, or biased content within the prompts given to the model to induce incorrect, inappropriate, or harmful responses.\n\nThe goal of such an attack is often to exploit vulnerabilities in how the AI processes and understands inputs, potentially leading to outputs that the developers or system users did not intend or expect. This can have various implications, including spreading misinformation, offensive content, or making the model behave unpredictably.\n\nMitigating prompt poisoning involves refining the model's ability to recognize and appropriately handle such inputs, incorporating safety and ethical guidelines, and continuously updating the model to handle new and evolving threats." additional_kwargs={'refusal': None} r
# ...

# %%
from langchain_groq import ChatGroq
from dotenv import load_dotenv

load_dotenv()

llm = ChatGroq(
    model="llama-3.1-8b-instant",
    max_tokens=1024
)

result = llm.invoke("What is Prompt Poisoning?")

print(result.content)
# Out:
# Prompt poisoning is a type of attack on large language models (LLMs) such as myself, where the attacker intentionally inputs a malicious or crafted input, known as a poisoned prompt, to manipulate the model's response. This can lead to the model producing incorrect, misleading, or even harmful information.
#
# There are several ways in which prompt poisoning can occur:
#
# 1. **Data poisoning**: The attacker feeds the model a large number of poisoned prompts, which are designed to corrupt the model's training data.
# 2. **Evasion attacks**: The attacker crafts a single poisoned prompt that is designed to evade the model's defenses and produce a specific, malicious response.
# 3. **Model extraction attacks**: The attacker uses a poisoned prompt to extract sensitive information from the model, such as its weights or internal state.
#
# Prompt poisoning can have serious consequences, including:
#
# ...

# %%
from langchain_anthropic import ChatAnthropic

from dotenv import load_dotenv

load_dotenv()

llm = ChatAnthropic(model="claude-haiku-4-5-20251001")

result = llm.invoke("What is Prompt Poisoning?")

print(result.content)
# Out:
# # Prompt Poisoning
#
# Prompt poisoning is a security attack where malicious data is injected into the training data or inputs of an AI system (particularly language models) to manipulate its behavior or outputs.
#
# ## How It Works
#
# **During Training:**
# - Attackers embed harmful instructions or data into training datasets
# - The model learns to follow these injected directives
# - The poisoning can be subtle and difficult to detect
#
# **During Use (Prompt Injection):**
# - Malicious instructions are included in user input
# - The model treats the injection as legitimate instruction
# - Can override the system's original intent
#
# ## Common Attack Scenarios
#
# | Type | Example |
# |------|---------|
# | **Biased outputs** | Training data with skewed perspectives causes biased responses |
# | **Instruction override** | Hidden commands within user input change model behavior |
# | **Backdoor triggers** | Specific phrases activate unintended behaviors |
# ...

# %% [markdown]
# ## ChatModel Conversation

# %%
from langchain_core.messages import AIMessage, HumanMessage, SystemMessage
from dotenv import load_dotenv

load_dotenv()

llm = ChatGroq(
    model="llama-3.1-8b-instant",
    max_tokens=1024
)

messages = [
    SystemMessage("You are expeert in philosophy and AI"),
    HumanMessage("Explain the AI concepts relating to Philosophy")
]

response = llm.invoke(messages)

print(response.content)
# Out:
# The intersection of Artificial Intelligence (AI) and Philosophy is a rich and rapidly expanding field, with implications for various branches of philosophy. Here are some key AI concepts relating to philosophy:
#
# 1. **The Turing Test**: Proposed by Alan Turing in 1950, this test assesses a machine's ability to exhibit intelligent behavior equivalent to, or indistinguishable from, that of a human. It raises questions about the nature of intelligence, consciousness, and the possibility of artificial intelligence.
#
# Philosophical connections: Mind-body dualism, functionalism, and the Chinese Room argument.
#
# 2. **Artificial Intelligence and Free Will**: As AI systems become increasingly sophisticated, questions arise about their ability to make decisions and act autonomously. This raises concerns about free will, moral responsibility, and the nature of agency.
#
# Philosophical connections: Libertarianism, compatibilism, and the problem of moral responsibility.
#
# ...
